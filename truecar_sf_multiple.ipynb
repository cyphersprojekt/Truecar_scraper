# %%
#Importar los módulos necesarios para el funcionamiento de nuestro programa
import requests
import pandas as pd

# %%
#cURL(cmd) Request del website convertida a Python utilizando curl.trillworks.com
headers = {
    'authority': 'www.truecar.com',
    'sec-ch-ua': '^\\^Google',
    'accept': 'application/json, text/plain, */*',
    'dnt': '1',
    'x-xsrf-token': 'MOTcqa/MOsWxJEEm8yFyLP/JeZoLZX51hsmYzizSoZHN/a8qXkoYdsBv5/hk9e5K2gkAR/IBLxbEzaxqKP7v/g==',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.truecar.com/used-cars-for-sale/listings/location-daly-city-ca/',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'referrer=ZTC0000000; _abp_auth_s=yzTPYfQMRiWI06WQx5CGb5zmaK7qRLSmUV7DeX0Affg; _abp_auth_p=eyJhbGciOiJIUzI1NiJ9.; tc_v=356fb25e-a436-4d1e-87e4-04616e8b8fe0; u=rBEAC2FJYFF2QQAQabF5Ag==; g_state=^{^\\^i_p^\\^:1632205953569,^\\^i_l^\\^:1^}; user_zip_code_new-york-ny=10001; user_zip_code_daly-city-ca=94016; capselaPreferredPostalCode=94016; XSRF-TOKEN=MOTcqa^%^2FMOsWxJEEm8yFyLP^%^2FJeZoLZX51hsmYzizSoZHN^%^2Fa8qXkoYdsBv5^%^2Fhk9e5K2gkAR^%^2FIBLxbEzaxqKP7v^%^2Fg^%^3D^%^3D; _abp_backend_session=R1FrYmZLemRSNUJSSDh3eDliOXNjaUtUN2pLV1dEVStISUJFamZYdC96bWJDYVdzUXdQWjA1MHFxOWsyY1Z4YjEvVVQxd0dVbVZXZGhkQWdaVUhwcmJHbnJuVWhsNk5PaVpMNDY5czdGekQ0SFcwaVM5VzBReDdielZJekx5Z2hBZE5ObXNaSTRIdGR6d1NiSmtEQThRPT0tLThUWXNqOER4WlhBcCtMM3hodHpLN1E9PQ^%^3D^%^3D--a4ed358ec851f343bae6d99c0448487e9f9fdf78; _dd_s=rum=0&expire=1632209695803',
}

# %%
#Crear listas vacías dentro de las que vamos a añadir la información que deseamos obtener del website
marca_sf = []
modelo_sf = []
año_sf = []
millaje_sf = []
precio_sf = []

# %%
#Loop que modifica la clave 'page' de nuestros parámetros para obtener la cantidad de resultados que deseamos
#Todas las variables y listas ahora deben estar dentro de este loop
#El funcionamiento en sí es un copy-paste del singular
for i in range(1,170): 
    params = (
    ('city', 'daly-city'),
    ('collapse', 'true'),
    ('fallback', 'true'),
    ('include_incentives', 'true'),
    ('include_targeted_incentives', 'true'),
    ('new_or_used', 'u'),
    ('page', str(i)),
    ('per_page', '30'),
    ('postal_code', '94016'),
    ('search_event', 'true'),
    ('sort^/[^/]', 'best_match'),
    ('sponsored', 'true'),
    ('state', 'ca'),
    )
    
    response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings', headers=headers, params=params)
    jsonresponse = response.json()
    listings = jsonresponse['listings']
    
    for i in range(len(listings)):
        marca_sf.append(listings[i]['vehicle']['make'])
        modelo_sf.append(listings[i]['vehicle']['model'])
        año_sf.append(listings[i]['vehicle']['year'])
        millaje_sf.append(listings[i]['vehicle']['mileage'])
        precio_sf.append(listings[i]['vehicle']['list_price'])

# %%
sfdf = pd.DataFrame({'Marca_sf':marca_sf, 'Modelo_sf':modelo_sf, 'Año_sf':año_sf, 'millaje_sf':millaje_sf, 'precio_sf':precio_sf})

# %%
sfdf.to_excel('sfdf5k.xlsx', index=False)
# Out:
#         Marca_sf        Modelo_sf  Año_sf  millaje_sf  precio_sf
# 0           FIAT             500e    2018       17067    15235.0
# 1            BMW               X3    2018       20759    33988.0
# 2           Ford            F-150    2019       20016    41994.0
# 3     Volkswagen            Jetta    2019       27687    20595.0
# 4           FIAT             500e    2018       18536    14985.0
# ...          ...              ...     ...         ...        ...
# 5065  Mitsubishi  Outlander Sport    2019       80059    15990.0
# 5066      Toyota          Corolla    2010       96782     8990.0
# 5067        Jeep         Wrangler    2018       45400    45999.0
# 5068         GMC      Sierra 1500    2017       36118    39590.0
# 5069        Ford          Mustang    2020       22068    30990.0
#
# [5070 rows x 5 columns]
